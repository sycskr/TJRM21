# %%
import argparse

import torch.backends.cudnn as cudnn

import numpy as np
import cv2 as cv

from models.experimental import *
from utils.datasets import *
from utils.utils import *

device_=''
weights='last_yolov5s_results.pt'
source='inference/t1.mp4' # file/folder, 0 for webcam
out='inference/output' # output folder
imgsz=640 #help='inference size (pixels)')
view_img='store_true'#'display results'
save_txt='store_true'# help='save results to *.txt')
    
#     parser.add_argument('--conf-thres', type=float, default=0.4, help='object confidence threshold')
#     parser.add_argument('--iou-thres', type=float, default=0.5, help='IOU threshold for NMS')
#     parser.add_argument('--device', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu')

#     parser.add_argument('--classes', nargs='+', type=int, help='filter by class: --class 0, or --class 0 2 3')
#     parser.add_argument('--agnostic-nms', action='store_true', help='class-agnostic NMS')
#     parser.add_argument('--augment', action='store_true', help='augmented inference')
#     parser.add_argument('--update', action='store_true', help='update all models')

# %%
 # Initialize
device = torch_utils.select_device(device_)
if os.path.exists(out):
    shutil.rmtree(out)  # delete output folder
os.makedirs(out)  # make new output folder
half = device.type != 'cpu'  # half precision only supported on CUDA
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='GeForce 940MX', total_memory=2004MB)

# %%
# Load model
model = attempt_load(weights, map_location=device)  # load FP32 model
imgsz = check_img_size(imgsz, s=model.stride.max())  # check img_size
if half:
    model.half()  # to FP16
# Out:
# Fusing layers... Model Summary: 120 layers, 6.8639e+06 parameters, 6.31725e+06 gradients
# /usr/local/lib/python3.7/site-packages/torch/serialization.py:657: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
# Get names and colors
names = model.module.names if hasattr(model, 'module') else model.names
colors = [[random.randint(0, 255) for _ in range(3)] for _ in range(len(names))]
# Run inference
t0 = time.time()
img = torch.zeros((1, 3, imgsz, imgsz), device=device)  # init img
_ = model(img.half() if half else img) if device.type != 'cpu' else None  # run once


cap=cv.VideoCapture("/home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4")#打开指定路径上的视频文件

while (True):
    ret,frame=cap.read()
    
    if ret == True:
        height, width = frame.shape[:2]
        matRotate = cv2.getRotationMatrix2D((height * 0.5, width * 0.5), -90, 1)
        frame = cv2.warpAffine(frame, matRotate, (width, height*2))
        cv.imshow("video",frame)
        # 在播放每一帧时，使用cv2.waitKey()设置适当的持续时间。如果设置的太低视频就会播放的非常快，如果设置的太高就会播放的很慢。通常情况下25ms就ok
        if cv2.waitKey(25)&0xFF==ord('q'):
            break
    else:
        break
 
cap.release()
cv.destroyAllWindows()

# %%
dataset = LoadImages(source, img_size=imgsz)
for path, img, im0s, vid_cap in dataset:
    #把数组转换成张量，且二者共享内存
    img = torch.from_numpy(img).to(device)
    img = img.half() if half else img.float()  # uint8 to fp16/32
    img /= 255.0  # 0 - 255 to 0.0 - 1.0
    if img.ndimension() == 3:
        img = img.unsqueeze(0)
    # Inference
    t1 = torch_utils.time_synchronized()
    pred = model(img, augment=opt.augment)[0]
# Out:
# video 1/1 (1/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (2/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 
903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (861/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (862/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (863/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (864/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (865/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (866/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (867/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (868/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (869/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (870/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (871/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (872/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (873/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (874/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (875/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (876/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (877/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (878/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (879/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (880/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (881/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (882/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (883/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (884/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (885/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (886/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (887/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (888/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (889/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (890/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (891/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (892/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (893/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (894/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (895/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (896/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (897/903) /home/truth/ClionProjects/mySITP/yolo/yolov5/inference/t1.mp4: video 1/1 (898/9 ...

# %%
for path, img, im0s, vid_cap in dataset:
        



        # Apply NMS
        pred = non_max_suppression(pred, opt.conf_thres, opt.iou_thres, classes=opt.classes, agnostic=opt.agnostic_nms)
        t2 = torch_utils.time_synchronized()

        # Apply Classifier
        if classify:
            pred = apply_classifier(pred, modelc, img, im0s)

        # Process detections
        for i, det in enumerate(pred):  # detections per image
            if webcam:  # batch_size >= 1
                p, s, im0 = path[i], '%g: ' % i, im0s[i].copy()
            else:
                p, s, im0 = path, '', im0s

            save_path = str(Path(out) / Path(p).name)
            txt_path = str(Path(out) / Path(p).stem) + ('_%g' % dataset.frame if dataset.mode == 'video' else '')
            s += '%gx%g ' % img.shape[2:]  # print string
            gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
            if det is not None and len(det):
                # Rescale boxes from img_size to im0 size
                det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()

                # Print results
                for c in det[:, -1].unique():
                    n = (det[:, -1] == c).sum()  # detections per class
                    s += '%g %ss, ' % (n, names[int(c)])  # add to string

                # Write results
                for *xyxy, conf, cls in det:
                    if save_txt:  # Write to file
                        xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()  # normalized xywh
                        with open(txt_path + '.txt', 'a') as f:
                            f.write(('%g ' * 5 + '\n') % (cls, *xywh))  # label format

                    if save_img or view_img:  # Add bbox to image
                        label = '%s %.2f' % (names[int(cls)], conf)
                        plot_one_box(xyxy, im0, label=label, color=colors[int(cls)], line_thickness=3)

            # Print time (inference + NMS)
            print('%sDone. (%.3fs)' % (s, t2 - t1))

            # Stream results
            if view_img:
                cv2.imshow(p, im0)
                if cv2.waitKey(1) == ord('q'):  # q to quit
                    raise StopIteration

            # Save results (image with detections)
            if save_img:
                if dataset.mode == 'images':
                    cv2.imwrite(save_path, im0)
                else:
                    if vid_path != save_path:  # new video
                        vid_path = save_path
                        if isinstance(vid_writer, cv2.VideoWriter):
                            vid_writer.release()  # release previous video writer

                        fourcc = 'mp4v'  # output video codec
                        fps = vid_cap.get(cv2.CAP_PROP_FPS)
                        w = int(vid_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                        h = int(vid_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                        vid_writer = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*fourcc), fps, (w, h))
                    vid_writer.write(im0)

    if save_txt or save_img:
        print('Results saved to %s' % os.getcwd() + os.sep + out)
        if platform == 'darwin' and not opt.update:  # MacOS
            os.system('open ' + save_path)

    print('Done. (%.3fs)' % (time.time() - t0))
